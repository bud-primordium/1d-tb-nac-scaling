# %% [markdown]
# # S2 Case 1′（延展-延展）

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.experiments_simple import case1_scaling
from src.visualization import setup_plot_style, plot_scaling, save_figure

setup_plot_style()

n_vals = [40, 80, 160, 320]

result = case1_scaling(
    n_vals=n_vals,
    r1=1 / 4,
    r2=3 / 8,
    t0=1.0,
    alpha=0.5,
    k_spring=1.0,
    temperature=300.0,
    a=1.0,
    mass=1.0,
    mode="classical",
)

fig, ax = plt.subplots(figsize=(6, 4))
plot_scaling(ax, result.n_vals, result.d2_vals, label="Case 1′", color="tab:blue")

save_figure(fig, "results/figures/S2_case1_scaling")
