# %% [markdown]
# # S3 Case 2（局域-局域）

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.experiments_simple import case2_scaling
from src.visualization import setup_plot_style, plot_scaling, save_figure

setup_plot_style()

n_vals = [40, 80, 160, 320]

result = case2_scaling(
    n_vals=n_vals,
    t0=1.0,
    alpha=0.5,
    k_spring=1.0,
    temperature=300.0,
    well_width=5,
    well_depth=-1.5,
    ipr_threshold=0.05,
    a=1.0,
    mass=1.0,
    mode="classical",
)

fig, ax = plt.subplots(figsize=(6, 4))
plot_scaling(ax, result.n_vals, result.d2_vals, label="Case 2", color="tab:orange")

save_figure(fig, "results/figures/S3_case2_scaling")
